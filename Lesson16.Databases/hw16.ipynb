# %% [markdown]
# ### Student table
#
# **Primary key** - student_id
#
# |student_id | Name | Age |
# |---|---|---|
# | 1 |Bae  | 18 |
# | 2 |Eddy | 21 |
# | 3 |Lily | 22 |
# | 4 |Jenny | 19 |
#
# ### Subject table
#
# **Primary key** - subject_id
#
# | subject_id | subject_name |
# |---|---|
# | 1 |English |
# | 2 |Spanish |
# | 3 |Chinese |
# | 4 |Math |
#
# ###  Student subject table
#
# **Primary key** - student_subject_id
#
# **Foreign key** - student_id, subject_id
#
# | student_id | subject_id |student_subject_id|
# |---|---|---|
# | 1 | 1 | 1 |
# | 1 | 2 | 2 |
# | 2 | 3 | 3 |
# | 3 | 1 | 4 |
# | 4 | 4 | 5 |

# %% [markdown]
# ### Practice
#
# 1. Add ability to create an `Exercise` and `Lesson` functionality. What tables should we create? Where is PK, FK in these tables?

# %% [markdown]
# ###  Lesson table
#
# **Primary key** - lesson_id
#
# **Foreign key** - subject_id, tutor_id
#
# | lesson_id | subject_id |datatime|tutor_id
# |---|---|---|---|
# | 1 | 1 | 24/07 | 1 |
# | 2 | 2 | 23/07 | 1 |
# | 3 | 3 | 21/07 | 2 |
# | 4 | 1 | 25/07 | 3 |
# | 5 | 4 | 27/07 | 3 |
#
# ###  Student_Lesson table
#
# **Primary key** - Student_Lesson_id
#
# **Foreign key** - lesson_id, student_id
#
# | Student_Lesson_id | lesson_id |student_id|
# |---|---|---|
# | 1 | 1 | 2 |
# | 2 | 1 | 4 |
# | 3 | 3 | 1 |
# | 4 | 3 | 3 |
# | 5 | 4 | 1 |
# | 6 | 5 | 3 |
# | 7 | 5 | 1 |

# %% [markdown]
# ###  Exercise table
#
# **Primary key** - exercise_id
#
# **Foreign key** - lesson_id
#
# | exercise_id | lesson_id | discription|deadline|
# |---|---|---|---|
# | 1 | 1 | something to do | 23/12 |
# | 2 | 1 | something to do | 21/12 |
# | 3 | 2 | something to do | 19/12 |
# | 4 | 2 | something to do | 31/12 |
# | 5 | 4 | something to do | 24/10 |
#
# 1. one to many
#
# На 1 уроке может выдаваться несколько заданий. Значит просто в таблицу Exercise table передаем ключ lesson_id
#
#
# 2. Many to many
#
# Одно и тоже задание может выдавать нескольким студентам
# И одному студенту может выдаваться несколько заданий
#
#
#
# Нужно создать еще одну таблицу Задание_Студент
# ###  Exercise_Student table
#
# **Primary key** - Exercise_Student_id
#
# **Foreign key** - student_id, exersise_id
#
# | exercise_student_id | student_id | exersise_id
# |---|---|---|
# | 1 | 1 | 1 |
# | 2 | 1 | 2 |
# | 3 | 2 | 1 |
# | 4 | 3 | 3 |
# | 5 | 4 | 3 |

# %% [markdown]
# ### Practice for homework
#
# Create a data model for a AirBnb.com system. Your model should give ability to store information about the users, the rooms, the reservations, and the reviews. You should have two types of users:
#
#     1. Hosts
#     2. Guests.
#
# Host should be able to create rooms with different attributes (amount of residents, price, A/C, refrigerator, etc.)
#
# Guest should be able to make a
#
#     1. Check availability of any rooms
#     2. Make Reservation for a room.
#
# For each table you should describe what is the primary key and what are the foreign keys (if any).
#
# Result of the work might be description in a table. You can create tables in text file with description of each field. You also can you any graphic tool that you might use to create data model. I usually use DRAW.io for such thing, but might choose another tool.
#
# (Optional): Add this possibilities for a guest
#
#     1. Pay for reservation
#     2. Review for the host.
#
# https://drawsql.app/teams/iaroslava-mixailenko/diagrams/hw-mykhailenko/embed
# https://drawsql.app/teams/iaroslava-mixailenko/diagrams/hw-mykhailenko/embed
